# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x = np.random.randint(10,60,(50))
print(x)
# Out:
# [39 50 59 50 51 44 28 49 54 58 19 37 14 10 40 28 59 22 28 45 39 37 57 27
#  44 34 12 20 53 36 14 38 21 53 20 58 42 48 17 32 49 22 50 50 27 37 10 45
#  19 12]

# %%
no = [39, 50, 59, 50, 51, 44, 28, 49, 54, 58, 19, 37, 14, 10, 40, 28, 59, 22, 28, 45, 39, 37, 57, 27, 44, 34, 12, 20, 53, 36, 14, 38, 21, 53, 20, 58, 42 ,48, 17, 32, 49, 22, 50, 50, 27, 37, 10, 45, 19, 12]

l = [10,20,30,40,50,60]
# color='y',bins=l
# 'auto',(0,200) 
# cumulative=-1  bottom=10 histtype="step" rwidth=0.8
plt.hist(no,edgecolor='g',log=2)

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("Number")

plt.axvline(45,color='y',label="line")

plt.legend()
plt.grid()
plt.show()
