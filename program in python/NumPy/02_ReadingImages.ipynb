# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('abishek.jpg')
plt.imshow(img)

# %%
img
# Out:
# array([[[176, 197, 214],
#         [176, 197, 214],
#         [176, 197, 214],
#         ...,
#         [177, 198, 217],
#         [179, 195, 208],
#         [189, 192, 197]],
#
#        [[176, 197, 214],
#         [176, 197, 214],
#         [176, 197, 214],
#         ...,
#         [177, 198, 217],
#         [179, 195, 208],
#         [189, 192, 197]],
#
#        [[177, 198, 215],
#         [177, 198, 215],
#         [177, 198, 215],
#         ...,
#         [177, 198, 217],
#         [179, 195, 208],
#         [189, 192, 197]],
#
#        ...,
#
#        [[203, 181, 132],
#         [203, 181, 131],
#         [203, 181, 132],
#         ...,
#         [218, 214, 185],
#         [216, 214, 191],
#         [217, 215, 202]],
#
#        [[196, 180, 144],
#         [196, 181, 142],
#         [196, 180, 144],
#         ...,
#         [215, 213, 192],
#         [215, 214, 196],
#         [217, 214, 205]],
#
#        [[182, 178, 167],
#         [182, 178, 166],
#         [182, 178, 167],
# ...

# %%
img.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : False
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
